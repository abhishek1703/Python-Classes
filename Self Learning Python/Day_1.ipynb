# %% [markdown]
# Python Bootcamp Day 1

# %% [markdown]
# Understnading print()
# The print() function displays output on the screen

# %%
print("Abhishek Day 1")
print("Day 1")
print("Way to learning Python")

# %% [markdown]
# Using Single and Multiple Variables

# %%
name = "Aadavan"
age = 4
city = "Faridabad"

print(name)
print(age)
print(city)
# Out:
# Aadavan
# 4
# Faridabad

# %%
name = 'abhishek'
print (name)
# Out:
# abhishek

# %% [markdown]
# Comments
#
# Comments are notes for humans.
#
# Python ignores them.

# %%
# This is a comment
print("Radha Rani")
# Out:
# Radha Rani

# %% [markdown]
# Printing Multiple Values

# %%
name = "Aadavan"
age = 4
print(name, age)
# Out:
# Aadavan 4

# %% [markdown]
# f-Strings (Very Important)
#
# Modern Python programmers use f-strings.

# %%
name = "Abhishek"
age = 38

print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Abhishek and I am 38 years old.

# %% [markdown]
# Real-World Example
#
# Suppose you are storing information about a learner.

# %%
student_name = "Aman"
course = "Python"
fees = 5000

print(f"{student_name} enrolled in {course}.")
print(f"Course fee is {fees}.")
# Out:
# Aman enrolled in Python.
# Course fee is 5000.

# %% [markdown]
# Practice Exercise 1
#
# Write a program to store:
# Name
# Age
# City
# Profession
# then print them

# %%
Name = "Aadavan"
Age = 4
City = "Agra"
Profession = "Student"
print(Name, Age, City, Profession)
# Out:
# Aadavan 4 Agra Student

# %% [markdown]
# Create
# book_name
# author_name
# price
# and display them using f-strings.

# %%
book_name = "English Teacher"
author_name = "R K Narayan"
price = 120

print (f"The book name is {book_name} written by {author_name} and its price is {price}.")
# Out:
# The book name is English Teacher written by R K Narayan and its price is 120.
