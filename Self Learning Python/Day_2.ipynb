# %% [markdown]
# Why Data Types?
#
# Suppose you're managing NIOS student records.
#
# A student's:
#
# Name → Abhishek
# Age → 38
# Percentage → 82.5
# Passed → Yes
#
# These are different kinds of data.
#
# Python needs to know what type of data it is handling.

# %% [markdown]
# 1. Integer (int)
#
# Whole numbers.
#
# Examples:
#
# age = 38
# marks = 85
# students = 500

# %%
# Check type:
age = 38

print(type(age))
# Out:
# <class 'int'>
