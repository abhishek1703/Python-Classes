# %% [markdown]
# This is markdown
# # Day 3
# print () baisc python

# %%
print("Abhishek")
# Out:
# Abhishek

# %%
a=3
b=7
add=a+b
sub=a-b
mul=a*b
div=b/a
print("add:", add, "Sub:", sub, "Mul: ", mul, "Div : ", div)
# Out:
# add: 10 Sub: -4 Mul:  21 Div :  2.3333333333333335
